# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/ML Project/Dataset/stocknet-dataset-master/price/raw/AAPL.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-09-04   95.108574   96.448570   94.928574   96.424286   87.121140
# 1     2012-09-05   96.510002   96.621429   95.657143   95.747147   86.509338
# 2     2012-09-06   96.167145   96.898575   95.828575   96.610001   87.288956
# 3     2012-09-07   96.864288   97.497147   96.538574   97.205711   87.827171
# 4     2012-09-10   97.207146   97.612854   94.585716   94.677139   85.542564
# ...          ...         ...         ...         ...         ...         ...
# 1253  2017-08-28  160.139999  162.000000  159.929993  161.470001  161.470001
# 1254  2017-08-29  160.100006  163.119995  160.000000  162.910004  162.910004
# 1255  2017-08-30  163.800003  163.889999  162.610001  163.350006  163.350006
# 1256  2017-08-31  163.639999  164.520004  163.479996  164.000000  164.000000
# 1257  2017-09-01  164.800003  164.940002  163.630005  164.050003  164.050003
#
#          Volume
# 0      91973000
# ...

# %%
df = df[333:837]
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 333  2014-01-02   79.382858   79.575714   78.860001   79.018570   73.522530
# 334  2014-01-03   78.980003   79.099998   77.204285   77.282860   71.907555
# 335  2014-01-06   76.778572   78.114288   76.228569   77.704285   72.299644
# 336  2014-01-07   77.760002   77.994286   76.845711   77.148575   71.782608
# 337  2014-01-08   76.972855   77.937141   76.955711   77.637146   72.237190
# ..          ...         ...         ...         ...         ...         ...
# 832  2015-12-24  109.000000  109.000000  107.949997  108.029999  104.380112
# 833  2015-12-28  107.589996  107.690002  106.180000  106.820000  103.210999
# 834  2015-12-29  106.959999  109.430000  106.860001  108.739998  105.066116
# 835  2015-12-30  108.580002  108.699997  107.180000  107.320000  103.694107
# 836  2015-12-31  107.010002  107.029999  104.820000  105.260002  101.703697
#
#         Volume
# 333   58671200
# 334   98116900
# ...

# %%
df.shape
# Out:
# (504, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 333 to 836
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       504 non-null    object
#  1   Open       504 non-null    float64
#  2   High       504 non-null    float64
#  3   Low        504 non-null    float64
#  4   Close      504 non-null    float64
#  5   Adj Close  504 non-null    float64
#  6   Volume     504 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 27.7+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  504.000000  504.000000  504.000000  504.000000  504.000000
# mean   106.197792  107.128594  105.169317  106.152327  100.986581
# std     17.737898   17.865823   17.494106   17.661503   17.579470
# min     70.739998   71.647141   70.507141   71.397141   66.431213
# 25%     93.997501   94.755001   93.119997   93.920002   88.401613
# 50%    110.265000  111.759998  108.800003  109.975003  105.387978
# 75%    120.792502  121.472500  119.299999  120.185000  115.442364
# max    134.460007  134.539993  131.399994  133.000000  126.941574
#
#              Volume
# count  5.040000e+02
# mean   5.749531e+07
# std    2.621951e+07
# min    1.304640e+07
# 25%    4.085560e+07
# 50%    5.151685e+07
# 75%    6.823910e+07
# max    2.663808e+08

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Open'].to_list(), marker="o", markersize=1, color="blue", linewidth=1, markeredgecolor="blue", label = 'Open Price' )
plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="red", linewidth=1, markeredgecolor="red", label = 'Close Price' )
plt.title('Open & Closing Stock Price - AAPL [2014-2015]')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['High'].to_list(), marker="o", markersize=1, color="blue", linewidth=1, markeredgecolor="blue", label = 'High Price' )
plt.plot(df['Low'].to_list(), marker="o", markersize=1, color="red", linewidth=1, markeredgecolor="red", label = 'Low Price' )
plt.title('Low and High Price - AAPL [2014-2015]')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
vol = df['Volume'].to_list()

vol = np.array(vol)
# vol = (vol/(5*1e6))+30

fig, ax = plt.subplots()

ax.grid()

ax.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price')
ax.tick_params(axis='y', labelcolor='black')

ax2 = ax.twinx()
ax2.plot(vol, marker="o", markersize=1, color="blue", linewidth=1, markeredgecolor="blue", label = 'Volume')
ax2.tick_params(axis='y', labelcolor='Blue')

ax2.legend()

ax.set_title("Volume v/s Stock Price")
# Out:
# Text(0.5, 1.0, 'Volume v/s Stock Price')

# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
from datetime import datetime
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
import plotly.figure_factory as ff

# %%
result = seasonal_decompose(df.Close, model='additive', period = 22)
fig = go.Figure()  
fig = result.plot()  
fig.set_size_inches(12, 17)

# %%
fig = go.Figure(data=[go.Candlestick(x=df.index[100:200],
                       open=df['Open'].to_list()[100:200], high=df['High'].to_list()[100:200],
                       low=df['Low'].to_list()[100:200], close=df['Close'].to_list()[100:200],
               increasing_line_color= 'green', decreasing_line_color= 'red')])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Project/Dataset/final_dataset (1).csv')
df = df.drop("Unnamed: 0",axis=1)
df
# Out:
#           Open1       Open2       Open3       Open4       Open5       High1  \
# 0     79.382858   79.167145   79.637146   80.545715   81.157143   79.575714
# 1     78.980003   79.382858   79.167145   79.637146   80.545715   79.099998
# 2     76.778572   78.980003   79.382858   79.167145   79.637146   78.114288
# 3     77.760002   76.778572   78.980003   79.382858   79.167145   77.994286
# 4     76.972855   77.760002   76.778572   78.980003   79.382858   77.937141
# ..          ...         ...         ...         ...         ...         ...
# 503  107.010002  108.580002  106.959999  107.589996  109.000000  107.029999
# 504  102.610001  107.010002  108.580002  106.959999  107.589996  105.370003
# 505  105.750000  102.610001  107.010002  108.580002  106.959999  105.849998
# 506  100.559998  105.750000  102.610001  107.010002  108.580002  102.370003
# 507   98.680000  100.559998  105.750000  102.610001  107.010002  100.129997
#
# ...

# %%
plt.figure(figsize=(30,24))
sns.heatmap(df.corr(), yticklabels='auto', annot=True, cmap='YlOrRd')
plt.savefig('heatmap.png')

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price' )
plt.plot(df['Positive5'].to_list(), marker="o", markersize=1, color="green", linewidth=1, markeredgecolor="green", label = 'Positive' )
plt.title('Tweet Sentiment and Stock Price Movement')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price' )
#plt.plot(df['Positive5'].to_list(), marker="o", markersize=1, color="green", linewidth=1, markeredgecolor="green", label = 'Positive' )
plt.plot(df['Neutral5'].to_list(), marker="o", markersize=1, color="blue", linewidth=1, markeredgecolor="blue", label = 'Neutral' )
#plt.plot(df['Negative5'].to_list(), marker="o", markersize=1, color="red", linewidth=1, markeredgecolor="red", label = 'Negative' )
plt.title('Tweet Sentiment and Stock Price Movement')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price' )
plt.plot(df['Positive5'].to_list(), marker="o", markersize=1, color="green", linewidth=1, markeredgecolor="green", label = 'Positive' )
plt.plot(df['Neutral5'].to_list(), marker="o", markersize=1, color="blue", linewidth=1, markeredgecolor="blue", label = 'Neutral' )
plt.plot(df['Negative5'].to_list(), marker="o", markersize=1, color="red", linewidth=1, markeredgecolor="red", label = 'Negative' )
plt.title('Tweet Sentiment and Stock Price Movement')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
sentiment_score = []
total_tweets = []
change = []

for i in range(len(df['Positive5'].to_list())) :

  sentiment_score.append(df['Positive5'].to_list()[i] - df['Negative5'].to_list()[i] + df['Positive4'].to_list()[i] - df['Negative4'].to_list()[i] + df['Positive3'].to_list()[i] - df['Negative3'].to_list()[i] )
  total_tweets.append((df['Positive5'].to_list()[i] + df['Negative5'].to_list()[i] + df['Neutral5'].to_list()[i] + df['Positive4'].to_list()[i] + df['Negative4'].to_list()[i] + df['Neutral4'].to_list()[i] + df['Positive3'].to_list()[i] + df['Negative3'].to_list()[i] + df['Neutral3'].to_list()[i])/3 )
  change.append((df['Close'].to_list()[i] - df['Close5'].to_list()[i]))

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price' )
plt.plot(sentiment_score, marker="o", markersize=1, color="purple", linewidth=1, markeredgecolor="purple", label = 'Sentiment Score' )
plt.plot(change, marker="o", markersize=1, color="indigo", linewidth=1, markeredgecolor="indigo", label = 'Delta' )
plt.title('Tweet Sentiment and Stock Price Movement')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price' )
plt.plot(change, marker="o", markersize=1, color="purple", linewidth=1, markeredgecolor="purple", label = 'Delta' )
plt.plot(total_tweets, marker="o", markersize=1, color="indigo", linewidth=1, markeredgecolor="indigo", label = 'Total Tweets' )
plt.title('Tweets Volume and Stock Price Movement')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True

# plt.xlim(xlim[0], xlim[1])
# plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.plot(df['Close'].to_list(), marker="o", markersize=1, color="black", linewidth=1, markeredgecolor="black", label = 'Close Price' )
plt.plot(df['Volume5'].to_list(), marker="o", markersize=1, color="red", linewidth=1, markeredgecolor="red", label = 'Volume' )
# plt.plot(total_tweets, marker="o", markersize=1, color="indigo", linewidth=1, markeredgecolor="indigo", label = 'Total Tweets' )
plt.title('Tweets Volume and Stock Price Movement')
plt.ylabel('Stock Price')
plt.xlabel('Time Series [2014-2015]')
plt.legend()
plt.show()
